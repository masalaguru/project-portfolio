# %% [markdown]
# <a href="https://colab.research.google.com/github/masalaguru/project-portfolio/blob/main/PSM_DID%20Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_excel('/content/광통신_광선로제거.xlsx')

# %%
df.to_excel('PSM_DID.xlsx', index=False)

# %%
df = pd.read_excel('/content/PSMDID_.xlsx')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   연번                 160 non-null    int64
#  1   업체명                160 non-null    object
#  2   중분류                160 non-null    object
#  3   업종코드               160 non-null    object
#  4   기업규모               160 non-null    object
#  5   기업규모(정비)           160 non-null    object
#  6   업력(2023년 기준)       160 non-null    int64
#  7   권역                 160 non-null    object
#  8   지역                 160 non-null    object
#  9   2018 상시근로자수(명)     83 non-null     float64
#  10  2019 상시근로자수(명)     107 non-null    float64
#  11  2020 상시근로자수(명)     91 non-null     float64
#  12  2021 상시근로자수(명)     74 non-null     float64
#  13  2022 상시근로자수_최근(명)  71 non-null     float64
#  14  매출액_2018           160 non-null    int64
#  15  매출액_2019           160 non-null    int64
# ...

# %%
df.describe()
# Out:
#                연번  업력(2023년 기준)  2018 상시근로자수(명)  2019 상시근로자수(명)  \
# count  160.000000    160.000000       83.000000      107.000000
# mean    80.500000     20.681250       74.819277       69.831776
# std     46.332134     10.218599       87.804959       86.717442
# min      1.000000      4.000000        2.000000        1.000000
# 25%     40.750000     14.000000       15.000000       12.000000
# 50%     80.500000     21.000000       37.000000       35.000000
# 75%    120.250000     25.000000      100.500000       79.000000
# max    160.000000     77.000000      444.000000      430.000000
#
#        2020 상시근로자수(명)  2021 상시근로자수(명)  2022 상시근로자수_최근(명)      매출액_2018  \
# count       91.000000       74.000000          71.000000  1.600000e+02
# mean        66.945055       72.959459          76.126761  2.127144e+07
# std         91.654589       96.127974          99.068220  6.660587e+07
# min          1.000000        0.000000           1.000000  0.000000e+00
# ...

# %%
df.groupby('참여여부').mean(numeric_only=True)
# Out:
#              연번  업력(2023년 기준)  2018 상시근로자수(명)  2019 상시근로자수(명)  2020 상시근로자수(명)  \
# 참여여부
# 0     84.875862     20.903448       69.506849       64.456522       58.075949
# 1     38.200000     18.533333      113.600000      102.800000      125.333333
#
#       2021 상시근로자수(명)  2022 상시근로자수_최근(명)      매출액_2018      매출액_2019  \
# 참여여부
# 0          61.359375          64.949153  2.025603e+07  2.436591e+07
# 1         147.200000         131.083333  3.108705e+07  5.521190e+07
#
#           매출액_2020  ...  부채총액_2018(천원)     부채총액_2019     부채총액_2020  \
# 참여여부                ...
# 0     2.113695e+07  ...   1.199829e+07  1.172167e+07  1.180172e+07
# 1     3.586271e+07  ...   1.650777e+07  2.010477e+07  1.934616e+07
#
#          부채총액_2021     부채총액_2022    연구개발비_2018    연구개발비_2019    연구개발비_2020  \
# 참여여부
# 0     1.328674e+07  1.679121e+07  1.036339e+06  1.080725e+06  1.199372e+06
# 1     2.317971e+07  2.348461e+07  2.874337e+06  3.272594e+06  3.721242e+06
#
#         연구개발비_2021    연구개발비_2022
# 참여여부
# ...

# %%
df.groupby('참여여부').std(numeric_only=True)

# %%
df.isnull().sum(axis=0)
# Out:
# 연번                    0
# 업체명                   0
# 중분류                   0
# 업종코드                  0
# 기업규모                  0
# 기업규모(정비)              0
# 업력(2023년 기준)          0
# 권역                    0
# 지역                    0
# 2018 상시근로자수(명)       77
# 2019 상시근로자수(명)       53
# 2020 상시근로자수(명)       69
# 2021 상시근로자수(명)       86
# 2022 상시근로자수_최근(명)    89
# 매출액_2018              0
# 매출액_2019              0
# 매출액_2020              0
# 매출액_2021              0
# 매출액_2022              0
# 부채총액_2018(천원)        13
# 부채총액_2019            10
# 부채총액_2020            10
# 부채총액_2021            14
# 부채총액_2022            24
# 연구개발비_2018            0
# 연구개발비_2019            0
# 연구개발비_2020            0
# 연구개발비_2021            0
# 연구개발비_2022            0
# 참여여부                  0
# dtype: int64
